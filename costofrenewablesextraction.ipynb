# %% [markdown]
# <a href="https://colab.research.google.com/github/theagegeshidze/theagegeshidze.github.io/blob/main/costofrenewablesextraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# import necessary packages

# %%
df = pd.read_csv('lazardextracted.csv')
#import data and convert into a dat q2

# %%
df
# Out:
#                     Type  Year  Mean LCOE
# 0   Solar PV Crystalline  2009        359
# 1   Solar PV Crystalline  2010        248
# 2   Solar PV Crystalline  2011        159
# 3   Solar PV Crystalline  2012        125
# 4   Solar PV Crystalline  2013        104
# ..                   ...   ...        ...
# 83            Gas Peaker  2015        192
# 84            Gas Peaker  2016        191
# 85            Gas Peaker  2017        183
# 86            Gas Peaker  2018        179
# 87            Gas Peaker  2019        175
#
# [88 rows x 3 columns]

# %%
df.T
#transpoe
# Out:
#                              0                     1                     2   \
# Type       Solar PV Crystalline  Solar PV Crystalline  Solar PV Crystalline
# Year                       2009                  2010                  2011
# Mean LCOE                   359                   248                   159
#
#                              3                     4                     5   \
# Type       Solar PV Crystalline  Solar PV Crystalline  Solar PV Crystalline
# Year                       2012                  2013                  2014
# Mean LCOE                   125                   104                    79
#
#                              6                     7                     8   \
# Type       Solar PV Crystalline  Solar PV Crystalline  Solar PV Crystalline
# Year                       2015                  2016                  2017
# Mean LCOE                    64                    55                    50
#
# ...

# %%
df.T.to_dict
# Out:
# <bound method DataFrame.to_dict of                              0                     1                     2   \
# Type       Solar PV Crystalline  Solar PV Crystalline  Solar PV Crystalline
# Year                       2009                  2010                  2011
# Mean LCOE                   359                   248                   159
#
#                              3                     4                     5   \
# Type       Solar PV Crystalline  Solar PV Crystalline  Solar PV Crystalline
# Year                       2012                  2013                  2014
# Mean LCOE                   125                   104                    79
#
#                              6                     7                     8   \
# Type       Solar PV Crystalline  Solar PV Crystalline  Solar PV Crystalline
# Year                       2015                  2016                  2017
# Mean LCOE                    64                    55                    50
#
# ...

# %%
list ( df.T.to_dict().values() ) #list  as values
# Out:
# [{'Type': 'Solar PV Crystalline', 'Year': 2009, 'Mean LCOE': 359},
#  {'Type': 'Solar PV Crystalline', 'Year': 2010, 'Mean LCOE': 248},
#  {'Type': 'Solar PV Crystalline', 'Year': 2011, 'Mean LCOE': 159},
#  {'Type': 'Solar PV Crystalline', 'Year': 2012, 'Mean LCOE': 125},
#  {'Type': 'Solar PV Crystalline', 'Year': 2013, 'Mean LCOE': 104},
#  {'Type': 'Solar PV Crystalline', 'Year': 2014, 'Mean LCOE': 79},
#  {'Type': 'Solar PV Crystalline', 'Year': 2015, 'Mean LCOE': 64},
#  {'Type': 'Solar PV Crystalline', 'Year': 2016, 'Mean LCOE': 55},
#  {'Type': 'Solar PV Crystalline', 'Year': 2017, 'Mean LCOE': 50},
#  {'Type': 'Solar PV Crystalline', 'Year': 2018, 'Mean LCOE': 43},
#  {'Type': 'Solar PV Crystalline', 'Year': 2019, 'Mean LCOE': 41},
#  {'Type': 'Wind', 'Year': 2009, 'Mean LCOE': 135},
#  {'Type': 'Wind', 'Year': 2010, 'Mean LCOE': 124},
#  {'Type': 'Wind', 'Year': 2011, 'Mean LCOE': 83},
#  {'Type': 'Wind', 'Year': 2012, 'Mean LCOE': 72},
# ...

# %%
exported_values = list( df.T.to_dict().values() )

# %%
exported_values
# Out:
# [{'Type': 'Solar PV Crystalline', 'Year': 2009, 'Mean LCOE': 359},
#  {'Type': 'Solar PV Crystalline', 'Year': 2010, 'Mean LCOE': 248},
#  {'Type': 'Solar PV Crystalline', 'Year': 2011, 'Mean LCOE': 159},
#  {'Type': 'Solar PV Crystalline', 'Year': 2012, 'Mean LCOE': 125},
#  {'Type': 'Solar PV Crystalline', 'Year': 2013, 'Mean LCOE': 104},
#  {'Type': 'Solar PV Crystalline', 'Year': 2014, 'Mean LCOE': 79},
#  {'Type': 'Solar PV Crystalline', 'Year': 2015, 'Mean LCOE': 64},
#  {'Type': 'Solar PV Crystalline', 'Year': 2016, 'Mean LCOE': 55},
#  {'Type': 'Solar PV Crystalline', 'Year': 2017, 'Mean LCOE': 50},
#  {'Type': 'Solar PV Crystalline', 'Year': 2018, 'Mean LCOE': 43},
#  {'Type': 'Solar PV Crystalline', 'Year': 2019, 'Mean LCOE': 41},
#  {'Type': 'Wind', 'Year': 2009, 'Mean LCOE': 135},
#  {'Type': 'Wind', 'Year': 2010, 'Mean LCOE': 124},
#  {'Type': 'Wind', 'Year': 2011, 'Mean LCOE': 83},
#  {'Type': 'Wind', 'Year': 2012, 'Mean LCOE': 72},
# ...

# %%
import json #export to be put into a graph

# %%
open('projectlazard.json', 'w').write( json.dumps(exported_values) )
# Out:
# 4862
