# %% [markdown]
# <a href="https://colab.research.google.com/github/theagegeshidze/theagegeshidze.github.io/blob/main/trellisedited.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
a = [2,4,3,"fdfd",[5,6]]

# %%
a
# Out:
# [2, 4, 3, 'fdfd', [5, 6]]

# %%
a[4][0]
# Out:
# 5

# %%
b={'alfa':1,
'beta':27, 
'gamma':[0,1,2],
'delta':67.3,
'ninety-eight':{
    'a': 5, 
    'b':7}
   }

# %%
b['ninety-eight']['a']
# Out:
# 5

# %%
b.keys(),b.values()
# Out:
# (dict_keys(['alfa', 'beta', 'gamma', 'delta', 'ninety-eight']),
#  dict_values([1, 27, [0, 1, 2], 67.3, {'a': 5, 'b': 7}]))

# %%
df = pd.read_csv('lowhightrellis.csv')

# %%
df
# Out:
#                            Entity  Year  Annual CO2 emissions Billion Tonnes
# 0           High-income countries  2000                            13.814314
# 1           High-income countries  2001                            13.768310
# 2           High-income countries  2002                            13.879006
# 3           High-income countries  2003                            14.132029
# 4           High-income countries  2004                            14.346497
# ..                            ...   ...                                  ...
# 83  Upper-middle-income countries  2017                            15.586029
# 84  Upper-middle-income countries  2018                            15.964710
# 85  Upper-middle-income countries  2019                            16.338437
# 86  Upper-middle-income countries  2020                            16.219840
# 87  Upper-middle-income countries  2021                            17.038822
#
# [88 rows x 3 columns]

# %%
df.T
# Out:
#                                                         0   \
# Entity                               High-income countries
# Year                                                  2000
# Annual CO2 emissions Billion Tonnes              13.814314
#
#                                                         1   \
# Entity                               High-income countries
# Year                                                  2001
# Annual CO2 emissions Billion Tonnes               13.76831
#
#                                                         2   \
# Entity                               High-income countries
# Year                                                  2002
# Annual CO2 emissions Billion Tonnes              13.879006
#
#                                                         3   \
# Entity                               High-income countries
# Year                                                  2003
# Annual CO2 emissions Billion Tonnes              14.132029
#
# ...

# %%
df.T.to_dict
# Out:
# <bound method DataFrame.to_dict of                                                         0   \
# Entity                               High-income countries
# Year                                                  2000
# Annual CO2 emissions Billion Tonnes              13.814314
#
#                                                         1   \
# Entity                               High-income countries
# Year                                                  2001
# Annual CO2 emissions Billion Tonnes               13.76831
#
#                                                         2   \
# Entity                               High-income countries
# Year                                                  2002
# Annual CO2 emissions Billion Tonnes              13.879006
#
#                                                         3   \
# Entity                               High-income countries
# Year                                                  2003
# ...

# %%
b.keys()
# Out:
# dict_keys(['alfa', 'beta', 'gamma', 'delta', 'ninety-eight'])

# %%
list ( df.T.to_dict().values() )
# Out:
# [{'Entity': 'High-income countries',
#   'Year': 2000,
#   'Annual CO2 emissions Billion Tonnes': 13.814314},
#  {'Entity': 'High-income countries',
#   'Year': 2001,
#   'Annual CO2 emissions Billion Tonnes': 13.76831},
#  {'Entity': 'High-income countries',
#   'Year': 2002,
#   'Annual CO2 emissions Billion Tonnes': 13.879006},
#  {'Entity': 'High-income countries',
#   'Year': 2003,
#   'Annual CO2 emissions Billion Tonnes': 14.132029},
#  {'Entity': 'High-income countries',
#   'Year': 2004,
#   'Annual CO2 emissions Billion Tonnes': 14.346497},
#  {'Entity': 'High-income countries',
#   'Year': 2005,
#   'Annual CO2 emissions Billion Tonnes': 14.392103},
#  {'Entity': 'High-income countries',
#   'Year': 2006,
#   'Annual CO2 emissions Billion Tonnes': 14.391346},
#  {'Entity': 'High-income countries',
#   'Year': 2007,
#   'Annual CO2 emissions Billion Tonnes': 14.503344},
#  {'Entity': 'High-income countries',
#   'Year': 2008,
# ...

# %%
exported_values = list( df.T.to_dict().values() )

# %%
exported_values
# Out:
# [{'Entity': 'High-income countries',
#   'Year': 2000,
#   'Annual CO2 emissions Billion Tonnes': 13.814314},
#  {'Entity': 'High-income countries',
#   'Year': 2001,
#   'Annual CO2 emissions Billion Tonnes': 13.76831},
#  {'Entity': 'High-income countries',
#   'Year': 2002,
#   'Annual CO2 emissions Billion Tonnes': 13.879006},
#  {'Entity': 'High-income countries',
#   'Year': 2003,
#   'Annual CO2 emissions Billion Tonnes': 14.132029},
#  {'Entity': 'High-income countries',
#   'Year': 2004,
#   'Annual CO2 emissions Billion Tonnes': 14.346497},
#  {'Entity': 'High-income countries',
#   'Year': 2005,
#   'Annual CO2 emissions Billion Tonnes': 14.392103},
#  {'Entity': 'High-income countries',
#   'Year': 2006,
#   'Annual CO2 emissions Billion Tonnes': 14.391346},
#  {'Entity': 'High-income countries',
#   'Year': 2007,
#   'Annual CO2 emissions Billion Tonnes': 14.503344},
#  {'Entity': 'High-income countries',
#   'Year': 2008,
# ...

# %%
import json

# %%
open('trellisweek9.json', 'w').write( json.dumps(exported_values) )
# Out:
# 9216
