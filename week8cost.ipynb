# %% [markdown]
# <a href="https://colab.research.google.com/github/theagegeshidze/theagegeshidze.github.io/blob/main/week8cost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/theagegeshidze/theagegeshidze.github.io/main/week8.csv')

# %%
df
# Out:
#         Date  Percentage                                 Category
# 0   Apr 2021       100.0                Lowest cost grocery items
# 1   May 2021       100.2                Lowest cost grocery items
# 2   Jun 2021        99.7                Lowest cost grocery items
# 3   Jul 2021       100.0                Lowest cost grocery items
# 4   Aug 2021       100.9                Lowest cost grocery items
# 5   Sep 2021        99.5                Lowest cost grocery items
# 6   Oct 2021       103.4                Lowest cost grocery items
# 7   Nov 2021       103.2                Lowest cost grocery items
# 8   Dec 2021       104.9                Lowest cost grocery items
# 9   Jan 2022       105.6                Lowest cost grocery items
# 10  Feb 2022       105.5                Lowest cost grocery items
# 11  Mar 2022       106.0                Lowest cost grocery items
# 12  Apr 2022       106.9                Lowest cost grocery items
# ...

# %%
df.T
# Out:
#                                    0                          1   \
# Date                         Apr 2021                   May 2021
# Percentage                      100.0                      100.2
# Category    Lowest cost grocery items  Lowest cost grocery items
#
#                                    2                          3   \
# Date                         Jun 2021                   Jul 2021
# Percentage                       99.7                      100.0
# Category    Lowest cost grocery items  Lowest cost grocery items
#
#                                    4                          5   \
# Date                         Aug 2021                   Sep 2021
# Percentage                      100.9                       99.5
# Category    Lowest cost grocery items  Lowest cost grocery items
#
#                                    6                          7   \
# Date                         Oct 2021                   Nov 2021
# ...

# %%
df.T.to_dict
# Out:
# <bound method DataFrame.to_dict of                                    0                          1   \
# Date                         Apr 2021                   May 2021
# Percentage                      100.0                      100.2
# Category    Lowest cost grocery items  Lowest cost grocery items
#
#                                    2                          3   \
# Date                         Jun 2021                   Jul 2021
# Percentage                       99.7                      100.0
# Category    Lowest cost grocery items  Lowest cost grocery items
#
#                                    4                          5   \
# Date                         Aug 2021                   Sep 2021
# Percentage                      100.9                       99.5
# Category    Lowest cost grocery items  Lowest cost grocery items
#
#                                    6                          7   \
# Date                         Oct 2021                   Nov 2021
# ...

# %%
b.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-987cf108996b> in <module>
# ----> 1 b.keys()
#
# NameError: name 'b' is not defined

# %%
list ( df.T.to_dict().values() )
# Out:
# [{'Date': 'Apr 2021',
#   'Percentage': 100.0,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'May 2021',
#   'Percentage': 100.2,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Jun 2021',
#   'Percentage': 99.7,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Jul 2021',
#   'Percentage': 100.0,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Aug 2021',
#   'Percentage': 100.9,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Sep 2021',
#   'Percentage': 99.5,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Oct 2021',
#   'Percentage': 103.4,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Nov 2021',
#   'Percentage': 103.2,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Dec 2021',
#   'Percentage': 104.9,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Jan 2022',
#   'Percentage': 105.6,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Feb 2022',
#   'Percentage': 105.5,
# ...

# %%
exported_values = list( df.T.to_dict().values() )

# %%
exported_values
# Out:
# [{'Date': 'Apr 2021',
#   'Percentage': 100.0,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'May 2021',
#   'Percentage': 100.2,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Jun 2021',
#   'Percentage': 99.7,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Jul 2021',
#   'Percentage': 100.0,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Aug 2021',
#   'Percentage': 100.9,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Sep 2021',
#   'Percentage': 99.5,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Oct 2021',
#   'Percentage': 103.4,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Nov 2021',
#   'Percentage': 103.2,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Dec 2021',
#   'Percentage': 104.9,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Jan 2022',
#   'Percentage': 105.6,
#   'Category': 'Lowest cost grocery items'},
#  {'Date': 'Feb 2022',
#   'Percentage': 105.5,
# ...

# %%
import json

# %%
open('week8_json.json', 'w').write( json.dumps(exported_values) )
# Out:
# 3271
