# %% [markdown]
# <a href="https://colab.research.google.com/github/theagegeshidze/theagegeshidze.github.io/blob/main/scrapingweek4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_html('https://en.wikipedia.org/wiki/Electricity_sector_in_France')
# Out:
# [                                                   0  \
#  0                                                NaN
#  1                                                NaN
#  2  Left: The Cattenom nuclear power station near ...
#
#                                                     1
#  0                                                NaN
#  1                                                NaN
#  2  Left: The Cattenom nuclear power station near ...  ,
#                                                 Data         Data.1
#  0                                Installed capacity         135 GW
#  1                                 Production (2020)      537.7 TWh
#  2  GHG emissions from electricity generation (2020)  57.3 gCO2/kWh,
#                                            Unnamed: 0  \
#  0                                               2004
#  1                                               2005
#  2                                               2006
# ...

# %%
solar_table = pd.read_html('https://en.wikipedia.org/wiki/Electricity_sector_in_France')
len(solar_table)
# Out:
# 7

# %%
solar_table[3]
# Out:
#     Unnamed: 0  Installed capacity [MW]  Production [TWh]
# 0      Nuclear                    61370             379.5
# 1   Hydropower                    25466              60.0
# 2   Wind power                    17391              34.1
# 3          Gas                    12529              38.6
# 4  Solar power                    10101              11.6
# 5         Coal                     2978               1.6
# 6          Oil                     2897               2.3
# 7  Bioenergies                     2160               9.9
# 8        Total                   134892             537.7

# %%
solar_table[3]
# Out:
#     Unnamed: 0  Installed capacity [MW]  Production [TWh]
# 0      Nuclear                    61370             379.5
# 1   Hydropower                    25466              60.0
# 2   Wind power                    17391              34.1
# 3          Gas                    12529              38.6
# 4  Solar power                    10101              11.6
# 5         Coal                     2978               1.6
# 6          Oil                     2897               2.3
# 7  Bioenergies                     2160               9.9
# 8        Total                   134892             537.7

# %%
df=solar_table[3]

# %%
df.T
# Out:
#                                0           1           2      3            4  \
# Unnamed: 0               Nuclear  Hydropower  Wind power    Gas  Solar power
# Installed capacity [MW]    61370       25466       17391  12529        10101
# Production [TWh]           379.5        60.0        34.1   38.6         11.6
#
#                             5     6            7       8
# Unnamed: 0               Coal   Oil  Bioenergies   Total
# Installed capacity [MW]  2978  2897         2160  134892
# Production [TWh]          1.6   2.3          9.9   537.7

# %%
print(df)
# Out:
#     Unnamed: 0  Installed capacity [MW]  Production [TWh]
# 0      Nuclear                    61370             379.5
# 1   Hydropower                    25466              60.0
# 2   Wind power                    17391              34.1
# 3          Gas                    12529              38.6
# 4  Solar power                    10101              11.6
# 5         Coal                     2978               1.6
# 6          Oil                     2897               2.3
# 7  Bioenergies                     2160               9.9
# 8        Total                   134892             537.7

# %%
print(df.shape)
# Out:
# (9, 3)

# %%
df.rename( columns={'Unnamed: 0':'Sources'}, inplace=True )

# %%
df.rename( columns={'Installed capacity [MW]':'Installed capacity'}, inplace=True )

# %%
print(df)
# Out:
#        Sources  Installed capacity  Production [TWh]
# 0      Nuclear               61370             379.5
# 1   Hydropower               25466              60.0
# 2   Wind power               17391              34.1
# 3          Gas               12529              38.6
# 4  Solar power               10101              11.6
# 5         Coal                2978               1.6
# 6          Oil                2897               2.3
# 7  Bioenergies                2160               9.9
# 8        Total              134892             537.7

# %%
df2=df.drop(df.columns[2], axis=1)

# %%
df2
# Out:
#        Sources  Installed capacity
# 0      Nuclear               61370
# 1   Hydropower               25466
# 2   Wind power               17391
# 3          Gas               12529
# 4  Solar power               10101
# 5         Coal                2978
# 6          Oil                2897
# 7  Bioenergies                2160
# 8        Total              134892

# %%
export_values = list(df2.T.to_dict().values())

# %%
export_values
# Out:
# [{'Sources': 'Nuclear', 'Installed capacity': 61370},
#  {'Sources': 'Hydropower', 'Installed capacity': 25466},
#  {'Sources': 'Wind power', 'Installed capacity': 17391},
#  {'Sources': 'Gas', 'Installed capacity': 12529},
#  {'Sources': 'Solar power', 'Installed capacity': 10101},
#  {'Sources': 'Coal', 'Installed capacity': 2978},
#  {'Sources': 'Oil', 'Installed capacity': 2897},
#  {'Sources': 'Bioenergies', 'Installed capacity': 2160},
#  {'Sources': 'Total', 'Installed capacity': 134892}]

# %%
import json

# %%
open('francesectorweek4.json', 'w').write(json.dumps(export_values))
# Out:
# 476
