# %% [markdown]
# <a href="https://colab.research.google.com/github/theagegeshidze/theagegeshidze.github.io/blob/main/WEEK3LATEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Arrays, vectors, `lists`
# Cell navigation: `Ctrl+Enter` runs the cell
# `Alt+Enter` runs and adds a new one below
# `Shift+Etner` runs and steps into the next cell

# %%
a = [2,4,3,"fdfd",[5,6]]

# %%
a
# Out:
# [2, 4, 3, 'fdfd', [5, 6]]

# %%
a[4][0]
# Out:
# 5

# %% [markdown]
# This is a nice **comments**
# Dictionary, Object, Hash table

# %%
b={'alfa':1,
'beta':27, 
'gamma':[0,1,2],
'delta':67.3,
'ninety-eight':{
    'a': 5, 
    'b':7}
   }

# %%
b['ninety-eight']['a']
# Out:
# 5

# %%
b.keys(),b.values()
# Out:
# (dict_keys(['alfa', 'beta', 'gamma', 'delta', 'ninety-eight']),
#  dict_values([1, 27, [0, 1, 2], 67.3, {'a': 5, 'b': 7}]))

# %%
import pandas as pd

# %%
df = pd.read_csv('cleanedbig4.csv')

# %%
df
# Out:
#      Year  Annual GDP Growth (%)  Country
# 0    1972               4.300341  Germany
# 1    1973               4.777487  Germany
# 2    1974               0.890069  Germany
# 3    1975              -0.866739  Germany
# 4    1976               4.949258  Germany
# ..    ...                    ...      ...
# 195  2017               1.667859    Italy
# 196  2018               0.925811    Italy
# 197  2019               0.500234    Italy
# 198  2020              -9.025669    Italy
# 199  2021               6.643790    Italy
#
# [200 rows x 3 columns]

# %%
df.head(5)
# Out:
#    Year  Annual GDP Growth (%)  Country
# 0  1972               4.300341  Germany
# 1  1973               4.777487  Germany
# 2  1974               0.890069  Germany
# 3  1975              -0.866739  Germany
# 4  1976               4.949258  Germany

# %%
df.T
# Out:
#                             0         1         2         3         4    \
# Year                       1972      1973      1974      1975      1976
# Annual GDP Growth (%)  4.300341  4.777487  0.890069 -0.866739  4.949258
# Country                 Germany   Germany   Germany   Germany   Germany
#
#                             5         6         7         8         9    ...  \
# Year                       1977      1978      1979      1980      1981  ...
# Annual GDP Growth (%)  3.347218  3.008493  4.150363  1.408829  0.529241  ...
# Country                 Germany   Germany   Germany   Germany   Germany  ...
#
#                             190       191       192       193       194  \
# Year                       2012      2013      2014      2015      2016
# Annual GDP Growth (%) -2.980906 -1.841065 -0.004548  0.778304  1.293463
# Country                   Italy     Italy     Italy     Italy     Italy
#
#                             195       196       197       198      199
# ...

# %%
df.T.to_dict
# Out:
# <bound method DataFrame.to_dict of                             0         1         2         3         4    \
# Year                       1972      1973      1974      1975      1976
# Annual GDP Growth (%)  4.300341  4.777487  0.890069 -0.866739  4.949258
# Country                 Germany   Germany   Germany   Germany   Germany
#
#                             5         6         7         8         9    ...  \
# Year                       1977      1978      1979      1980      1981  ...
# Annual GDP Growth (%)  3.347218  3.008493  4.150363  1.408829  0.529241  ...
# Country                 Germany   Germany   Germany   Germany   Germany  ...
#
#                             190       191       192       193       194  \
# Year                       2012      2013      2014      2015      2016
# Annual GDP Growth (%) -2.980906 -1.841065 -0.004548  0.778304  1.293463
# Country                   Italy     Italy     Italy     Italy     Italy
#
# ...

# %%
b.keys()
# Out:
# dict_keys(['alfa', 'beta', 'gamma', 'delta', 'ninety-eight'])

# %%
list ( df.T.to_dict().values() )
# Out:
# [{'Year': 1972, 'Annual GDP Growth (%)': 4.300341334, 'Country': 'Germany'},
#  {'Year': 1973, 'Annual GDP Growth (%)': 4.777486892, 'Country': 'Germany'},
#  {'Year': 1974, 'Annual GDP Growth (%)': 0.890068741, 'Country': 'Germany'},
#  {'Year': 1975, 'Annual GDP Growth (%)': -0.866738894, 'Country': 'Germany'},
#  {'Year': 1976, 'Annual GDP Growth (%)': 4.949258377, 'Country': 'Germany'},
#  {'Year': 1977, 'Annual GDP Growth (%)': 3.34721812, 'Country': 'Germany'},
#  {'Year': 1978, 'Annual GDP Growth (%)': 3.008492857, 'Country': 'Germany'},
#  {'Year': 1979, 'Annual GDP Growth (%)': 4.150363341, 'Country': 'Germany'},
#  {'Year': 1980, 'Annual GDP Growth (%)': 1.408828636, 'Country': 'Germany'},
#  {'Year': 1981, 'Annual GDP Growth (%)': 0.529240557, 'Country': 'Germany'},
#  {'Year': 1982, 'Annual GDP Growth (%)': -0.394840775, 'Country': 'Germany'},
#  {'Year': 1983, 'Annual GDP Growth (%)': 1.57241017, 'Country': 'Germany'},
# ...

# %%
exported_values = list( df.T.to_dict().values() )

# %%
exported_values
# Out:
# [{'Year': 1972, 'Annual GDP Growth (%)': 4.300341334, 'Country': 'Germany'},
#  {'Year': 1973, 'Annual GDP Growth (%)': 4.777486892, 'Country': 'Germany'},
#  {'Year': 1974, 'Annual GDP Growth (%)': 0.890068741, 'Country': 'Germany'},
#  {'Year': 1975, 'Annual GDP Growth (%)': -0.866738894, 'Country': 'Germany'},
#  {'Year': 1976, 'Annual GDP Growth (%)': 4.949258377, 'Country': 'Germany'},
#  {'Year': 1977, 'Annual GDP Growth (%)': 3.34721812, 'Country': 'Germany'},
#  {'Year': 1978, 'Annual GDP Growth (%)': 3.008492857, 'Country': 'Germany'},
#  {'Year': 1979, 'Annual GDP Growth (%)': 4.150363341, 'Country': 'Germany'},
#  {'Year': 1980, 'Annual GDP Growth (%)': 1.408828636, 'Country': 'Germany'},
#  {'Year': 1981, 'Annual GDP Growth (%)': 0.529240557, 'Country': 'Germany'},
#  {'Year': 1982, 'Annual GDP Growth (%)': -0.394840775, 'Country': 'Germany'},
#  {'Year': 1983, 'Annual GDP Growth (%)': 1.57241017, 'Country': 'Germany'},
# ...

# %%
import json

# %%
# json.dumps(exported_values)

# %%
open('week3_json.json', 'w').write( json.dumps(exported_values) )
# Out:
# 15412
